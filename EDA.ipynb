# %%
import pandas as pd

# %%
df = pd.read_csv('application_train.csv')

# %%
df = df.loc[:, ['SK_ID_CURR', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'TARGET']]
df.head()
# Out:
#    SK_ID_CURR CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  TARGET
# 0      100002           M            N               Y             0       1
# 1      100003           F            N               N             0       0
# 2      100004           M            Y               Y             0       0
# 3      100006           F            N               Y             0       0
# 4      100007           M            N               Y             0       0

# %%
df.isna().sum()
# Out:
# SK_ID_CURR         0
# CODE_GENDER        0
# FLAG_OWN_CAR       0
# FLAG_OWN_REALTY    0
# CNT_CHILDREN       0
# TARGET             0
# dtype: int64

# %%
df.dtypes
# Out:
# SK_ID_CURR          int64
# CODE_GENDER        object
# FLAG_OWN_CAR       object
# FLAG_OWN_REALTY    object
# CNT_CHILDREN        int64
# TARGET              int64
# dtype: object

# %%
df2 = pd.read_csv('previous_application.csv')
df2.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %%
df2 = df2.loc[:, ['SK_ID_PREV', 'SK_ID_CURR','NAME_CONTRACT_STATUS']]
df2.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_STATUS
# 0     2030495      271877             Approved
# 1     2802425      108129             Approved
# 2     2523466      122040             Approved
# 3     2819243      176158             Approved
# 4     1784265      202054              Refused

# %%
df2.isna().sum()
# Out:
# SK_ID_PREV              0
# SK_ID_CURR              0
# NAME_CONTRACT_STATUS    0
# dtype: int64

# %%
df3.groupby('NAME_CONTRACT_STATUS')['SK_ID_PREV'].count().to_frame().head()
# Out:
#                       SK_ID_PREV
# NAME_CONTRACT_STATUS
# Approved                  886076
# Canceled                  259434
# Refused                   245365
# Unused offer               22771

# %%
df2.dtypes
# Out:
# SK_ID_PREV               int64
# SK_ID_CURR               int64
# NAME_CONTRACT_STATUS    object
# dtype: object

# %%
df3 = pd.merge(df2,df, on = 'SK_ID_CURR', how='inner')
df3.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0     2030495      271877             Approved           F            N
# 1     1696966      271877              Refused           F            N
# 2     2154916      271877             Approved           F            N
# 3     2802425      108129             Approved           F            N
# 4     1536272      108129             Approved           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  TARGET
# 0               Y             1       0
# 1               Y             1       0
# 2               Y             1       0
# 3               N             0       0
# 4               N             0       0

# %%
df3.isna().sum()
# Out:
# SK_ID_CURR              0
# CODE_GENDER             0
# FLAG_OWN_CAR            0
# FLAG_OWN_REALTY         0
# CNT_CHILDREN            0
# TARGET                  0
# SK_ID_PREV              0
# NAME_CONTRACT_STATUS    0
# dtype: int64

# %%
df3.groupby('NAME_CONTRACT_STATUS')['SK_ID_CURR'].count().to_frame().head()
# Out:
#                       SK_ID_CURR
# NAME_CONTRACT_STATUS
# Approved                  886076
# Canceled                  259434
# Refused                   245365
# Unused offer               22771

# %%
df3.groupby('CODE_GENDER')['SK_ID_CURR'].count().to_frame().head()
# Out:
#              SK_ID_CURR
# CODE_GENDER
# F                955139
# M                458507
# XNA                  55

# %%
df31 = df3[(df3['CODE_GENDER']=='XNA')]
df31.head()
# Out:
#         SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_STATUS CODE_GENDER FLAG_OWN_CAR  \
# 307969     1298947      319880             Approved         XNA            Y
# 307970     2208449      319880             Approved         XNA            Y
# 307971     2460063      319880             Approved         XNA            Y
# 307972     2121639      319880              Refused         XNA            Y
# 307973     2811696      319880              Refused         XNA            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  TARGET
# 307969               Y             0       0
# 307970               Y             0       0
# 307971               Y             0       0
# 307972               Y             0       0
# 307973               Y             0       0

# %%
df3 = df3[df3.CODE_GENDER != 'XNA']
df3
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0           2030495      271877             Approved           F            N
# 1           1696966      271877              Refused           F            N
# 2           2154916      271877             Approved           F            N
# 3           2802425      108129             Approved           F            N
# 4           1536272      108129             Approved           F            N
# ...             ...         ...                  ...         ...          ...
# 1413696     1261221      277978             Approved           F            N
# 1413697     1563733      227766             Approved           F            Y
# 1413698     2319569      239799             Approved           F            N
# 1413699     2829648      353284             Approved           F            N
# 1413700     1944034      191629             Canceled           F            N
#
# ...

# %%
df3.groupby('CODE_GENDER')['SK_ID_CURR'].count().to_frame().head()
# Out:
#              SK_ID_CURR
# CODE_GENDER
# F                955139
# M                458507

# %%
df3.to_csv('EDA.csv', sep=',', index = False)
